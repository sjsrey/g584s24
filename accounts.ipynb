# %%
import pandas

# %%
df = pandas.read_csv('2024-01-23T1031_Grades-GEOG584-01-Spr2024.csv')

# %%
df.head()
# Out:
#                Student        ID  SIS User ID           SIS Login ID  \
# 0      Points Possible       NaN          NaN                    NaN
# 1       Bartel, Gracie  139140.0  828408289.0   gbartel2616@sdsu.edu
# 2         Carr, Daniel   46212.0  824409957.0     dcarr6178@sdsu.edu
# 3  Flores, Christopher  147495.0  827625962.0   cflores3051@sdsu.edu
# 4        Higashi, Cara  137945.0  822856457.0  chigashi1194@sdsu.edu
#
#       Section Assignments Current Points Assignments Final Points  \
# 0         NaN                (read only)              (read only)
# 1  Section 01                       0.00                     0.00
# 2  Section 01                       0.00                     0.00
# 3  Section 01                       0.00                     0.00
# 4  Section 01                       0.00                     0.00
#
#   Assignments Current Score Assignments Unposted Current Score  \
# 0               (read only)                        (read only)
# ...

# %%
pandas.read_csv?
# Out:
# Signature:
# pandas.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'list[HashableT] | Callable[[Hashable], bool] | None' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
# ...

# %%
df = pandas.read_csv('2024-01-23T1031_Grades-GEOG584-01-Spr2024.csv', skiprows=1)

# %%
df.head()
# Out:
#        Points Possible  Unnamed: 1  Unnamed: 2             Unnamed: 3  \
# 0       Bartel, Gracie      139140   828408289   gbartel2616@sdsu.edu
# 1         Carr, Daniel       46212   824409957     dcarr6178@sdsu.edu
# 2  Flores, Christopher      147495   827625962   cflores3051@sdsu.edu
# 3        Higashi, Cara      137945   822856457  chigashi1194@sdsu.edu
# 4           Huang, Jin      181706   130381469    jhuang7158@sdsu.edu
#
#    Unnamed: 4  (read only)  (read only).1  (read only).2  (read only).3  \
# 0  Section 01          0.0            0.0            NaN            NaN
# 1  Section 01          0.0            0.0            NaN            NaN
# 2  Section 01          0.0            0.0            NaN            NaN
# 3  Section 01          0.0            0.0            NaN            NaN
# 4  Section 01          0.0            0.0            NaN            NaN
#
#    (read only).4  (read only).5  (read only).6  (read only).7  (read only).8  \
# ...

# %%
df.iloc[:,3]
# Out:
# 0            gbartel2616@sdsu.edu
# 1              dcarr6178@sdsu.edu
# 2            cflores3051@sdsu.edu
# 3           chigashi1194@sdsu.edu
# 4             jhuang7158@sdsu.edu
# 5               hlee5571@sdsu.edu
# 6             rlopez0441@sdsu.edu
# 7         cmckinstry0535@sdsu.edu
# 8             solsen4673@sdsu.edu
# 9           jornelas3843@sdsu.edu
# 10    gramosgutierre6486@sdsu.edu
# 11       msiebenthal9051@sdsu.edu
# 12               jsy8036@sdsu.edu
# 13             jwang0108@sdsu.edu
# Name: Unnamed: 3, dtype: object

# %%
names = df.iloc[:,3].values

# %%
names
# Out:
# array(['gbartel2616@sdsu.edu', 'dcarr6178@sdsu.edu',
#        'cflores3051@sdsu.edu', 'chigashi1194@sdsu.edu',
#        'jhuang7158@sdsu.edu', 'hlee5571@sdsu.edu', 'rlopez0441@sdsu.edu',
#        'cmckinstry0535@sdsu.edu', 'solsen4673@sdsu.edu',
#        'jornelas3843@sdsu.edu', 'gramosgutierre6486@sdsu.edu',
#        'msiebenthal9051@sdsu.edu', 'jsy8036@sdsu.edu',
#        'jwang0108@sdsu.edu'], dtype=object)

# %%
names = [ name.split("@")[0] for name in names]

# %%
names
# Out:
# ['gbartel2616',
#  'dcarr6178',
#  'cflores3051',
#  'chigashi1194',
#  'jhuang7158',
#  'hlee5571',
#  'rlopez0441',
#  'cmckinstry0535',
#  'solsen4673',
#  'jornelas3843',
#  'gramosgutierre6486',
#  'msiebenthal9051',
#  'jsy8036',
#  'jwang0108']

# %%
with open('accounts.csv', 'w') as f:
    f.write("\n".join(names))

# %%
# !cat accounts.csv
# Out:
# gbartel2616
# dcarr6178
# cflores3051
# chigashi1194
# jhuang7158
# hlee5571
# rlopez0441
# cmckinstry0535
# solsen4673
# jornelas3843
# gramosgutierre6486
# msiebenthal9051
# jsy8036
# jwang0108
